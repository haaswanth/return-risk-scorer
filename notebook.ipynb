# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
data = pd.read_csv("ecommerce_returns.csv")

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ## Initial Data Exploring

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.columns
# Out:
# Index(['Order_Date', 'Product_Category', 'Product_Price', 'Order_Quantity',
#        'Discount_Applied', 'Shipping_Method', 'Payment_Method', 'User_Age',
#        'User_Gender', 'User_Location', 'Return_Status', 'Order_Value'],
#       dtype='str')

# %%
df.head(5)
# Out:
#    Order_Date Product_Category  Product_Price  Order_Quantity  \
# 0  2022-01-14         Clothing        1720.71               2
# 1  2022-01-03             Toys         744.06               5
# 2  2025-03-16         Clothing         983.68               5
# 3  2024-11-06            Books        1855.65               2
# 4  2023-06-07  Home Appliances        1770.97               5
#
#    Discount_Applied Shipping_Method Payment_Method  User_Age User_Gender  \
# 0             30.46        Next-Day         Wallet        57      Female
# 1             29.62        Next-Day         Wallet        55      Female
# 2             47.80         Express         Wallet        37      Female
# 3              2.90         Express            COD        47      Female
# 4             44.42         Express            COD        35      Female
#
#   User_Location Return_Status  Order_Value
# 0        City27  Not Returned  2393.163468
# 1         City5      Returned  2618.347140
# ...

# %%
df.tail(5)
# Out:
#       Order_Date Product_Category  Product_Price  Order_Quantity  \
# 4995  2024-08-12         Clothing        1729.90               5
# 4996  2024-08-25            Books        1254.75               4
# 4997  2023-11-15         Clothing        1183.28               3
# 4998  2024-01-03            Books        1761.47               4
# 4999  2025-08-08      Electronics        1975.01               1
#
#       Discount_Applied Shipping_Method Payment_Method  User_Age User_Gender  \
# 4995              4.50        Next-Day     Debit Card        27        Male
# 4996             32.73         Express            COD        61      Female
# 4997             31.03        Standard     Debit Card        59        Male
# 4998             11.30         Express         Wallet        43        Male
# 4999             39.85         Express         Wallet        49      Female
#
#      User_Location Return_Status  Order_Value
# 4995        City82  Not Returned  8260.272500
# ...

# %%
df.describe()
# Out:
#        Product_Price  Order_Quantity  Discount_Applied     User_Age  \
# count    5000.000000     5000.000000       5000.000000  5000.000000
# mean     1054.294740        2.997600         25.011476    41.551800
# std       548.560406        1.400709         14.430681    13.890195
# min       100.090000        1.000000          0.000000    18.000000
# 25%       580.937500        2.000000         12.827500    30.000000
# 50%      1044.850000        3.000000         25.020000    42.000000
# 75%      1530.835000        4.000000         37.380000    54.000000
# max      1999.800000        5.000000         50.000000    65.000000
#
#        Order_Value
# count  5000.000000
# mean   2366.996469
# std    1834.851991
# min      52.165727
# 25%     928.078449
# 50%    1864.584054
# 75%    3382.309799
# max    9827.017200

# %%
df.info
# Out:
# <bound method DataFrame.info of       Order_Date Product_Category  Product_Price  Order_Quantity  \
# 0     2022-01-14         Clothing        1720.71               2
# 1     2022-01-03             Toys         744.06               5
# 2     2025-03-16         Clothing         983.68               5
# 3     2024-11-06            Books        1855.65               2
# 4     2023-06-07  Home Appliances        1770.97               5
# ...          ...              ...            ...             ...
# 4995  2024-08-12         Clothing        1729.90               5
# 4996  2024-08-25            Books        1254.75               4
# 4997  2023-11-15         Clothing        1183.28               3
# 4998  2024-01-03            Books        1761.47               4
# 4999  2025-08-08      Electronics        1975.01               1
#
#       Discount_Applied Shipping_Method Payment_Method  User_Age User_Gender  \
# 0                30.46        Next-Day         Wallet        57      Female
# ...

# %%
df.isnull()
# Out:
#       Order_Date  Product_Category  Product_Price  Order_Quantity  \
# 0          False             False          False           False
# 1          False             False          False           False
# 2          False             False          False           False
# 3          False             False          False           False
# 4          False             False          False           False
# ...          ...               ...            ...             ...
# 4995       False             False          False           False
# 4996       False             False          False           False
# 4997       False             False          False           False
# 4998       False             False          False           False
# 4999       False             False          False           False
#
#       Discount_Applied  Shipping_Method  Payment_Method  User_Age  \
# 0                False            False           False     False
# ...

# %%
df.isnull().sum()
# Out:
# Order_Date          0
# Product_Category    0
# Product_Price       0
# Order_Quantity      0
# Discount_Applied    0
# Shipping_Method     0
# Payment_Method      0
# User_Age            0
# User_Gender         0
# User_Location       0
# Return_Status       0
# Order_Value         0
# dtype: int64

# %%
df.dtypes
# Out:
# Order_Date              str
# Product_Category        str
# Product_Price       float64
# Order_Quantity        int64
# Discount_Applied    float64
# Shipping_Method         str
# Payment_Method          str
# User_Age              int64
# User_Gender             str
# User_Location           str
# Return_Status           str
# Order_Value         float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleanning

# %%
df.isnull().sum()
# Out:
# Order_Date          0
# Product_Category    0
# Product_Price       0
# Order_Quantity      0
# Discount_Applied    0
# Shipping_Method     0
# Payment_Method      0
# User_Age            0
# User_Gender         0
# User_Location       0
# Return_Status       0
# Order_Value         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df.head(1)
# Out:
#    Order_Date Product_Category  Product_Price  Order_Quantity  \
# 0  2022-01-14         Clothing        1720.71               2
#
#    Discount_Applied Shipping_Method Payment_Method  User_Age User_Gender  \
# 0             30.46        Next-Day         Wallet        57      Female
#
#   User_Location Return_Status  Order_Value
# 0        City27  Not Returned  2393.163468

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Return_Status', data=df)

plt.title('Return Status Distribution')
plt.xlabel('Return Status')
plt.ylabel('Count')
plt.show()

# %%
num_features = [
    'Product_Price',
    'Order_Quantity',
    'Discount_Applied',
    'User_Age',
    'Order_Value'
]

for col in num_features:
    sns.boxplot(x=df[col])
    plt.title(f'{col} Distribution')
    plt.show()

# %%
sns.countplot(data=df, x='Product_Category')

plt.title('Product Category Distribution')
plt.xlabel('Product Category')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x='Shipping_Method')

plt.title('Shipping Method Distribution')
plt.xlabel('Shipping Method')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x='Payment_Method')

plt.title('Payment Method Distribution')
plt.xlabel('Payment Method')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x='User_Gender')

plt.title('User Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Orders')
plt.show()

# %%
sns.countplot(data=df, x='User_Location')

plt.title('User Location Distribution')
plt.xlabel('Location')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df["year"] = df['Order_Date'].dt.year
df['month'] = df['Order_Date'].dt.month
df['day'] = df['Order_Date'].dt.day

# %%
df.head(1)
# Out:
#   Order_Date Product_Category  Product_Price  Order_Quantity  \
# 0 2022-01-14         Clothing        1720.71               2
#
#    Discount_Applied Shipping_Method Payment_Method  User_Age User_Gender  \
# 0             30.46        Next-Day         Wallet        57      Female
#
#   User_Location Return_Status  Order_Value  year  month  day
# 0        City27  Not Returned  2393.163468  2022      1   14

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing           1766
# Electronics        1244
# Books               762
# Toys                752
# Home Appliances     476
# Name: count, dtype: int64

# %%
df['Shipping_Method'].value_counts()
# Out:
# Shipping_Method
# Next-Day    1684
# Standard    1683
# Express     1633
# Name: count, dtype: int64

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Debit Card     1277
# Wallet         1275
# Credit Card    1235
# COD            1213
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Order_Date          datetime64[us]
# Product_Category               str
# Product_Price              float64
# Order_Quantity               int64
# Discount_Applied           float64
# Shipping_Method                str
# Payment_Method                 str
# User_Age                     int64
# User_Gender                    str
# User_Location                  str
# Return_Status                  str
# Order_Value                float64
# year                         int32
# month                        int32
# day                          int32
# dtype: object

# %%
df.head(1)
# Out:
#   Order_Date Product_Category  Product_Price  Order_Quantity  \
# 0 2022-01-14         Clothing        1720.71               2
#
#    Discount_Applied Shipping_Method Payment_Method  User_Age User_Gender  \
# 0             30.46        Next-Day         Wallet        57      Female
#
#   User_Location Return_Status  Order_Value  year  month  day
# 0        City27  Not Returned  2393.163468  2022      1   14

# %%
df = pd.get_dummies(df,columns = ['Product_Category','Shipping_Method','Payment_Method','User_Gender'])

# %%
df.head(1)
# Out:
#   Order_Date  Product_Price  Order_Quantity  Discount_Applied  User_Age  \
# 0 2022-01-14        1720.71               2             30.46        57
#
#   User_Location Return_Status  Order_Value  year  month  ...  \
# 0        City27  Not Returned  2393.163468  2022      1  ...
#
#    Product_Category_Toys  Shipping_Method_Express  Shipping_Method_Next-Day  \
# 0                  False                    False                      True
#
#    Shipping_Method_Standard  Payment_Method_COD  Payment_Method_Credit Card  \
# 0                     False               False                       False
#
#    Payment_Method_Debit Card  Payment_Method_Wallet  User_Gender_Female  \
# 0                      False                   True                True
#
#    User_Gender_Male
# 0             False
#
# [1 rows x 25 columns]

# %%
df['Return_Status'] = df['Return_Status'].map({'Not Returned':0,'Returned':1})

# %%
df.head(1)
# Out:
#   Order_Date  Product_Price  Order_Quantity  Discount_Applied  User_Age  \
# 0 2022-01-14        1720.71               2             30.46        57
#
#   User_Location  Return_Status  Order_Value  year  month  ...  \
# 0        City27              0  2393.163468  2022      1  ...
#
#    Product_Category_Toys  Shipping_Method_Express  Shipping_Method_Next-Day  \
# 0                  False                    False                      True
#
#    Shipping_Method_Standard  Payment_Method_COD  Payment_Method_Credit Card  \
# 0                     False               False                       False
#
#    Payment_Method_Debit Card  Payment_Method_Wallet  User_Gender_Female  \
# 0                      False                   True                True
#
#    User_Gender_Male
# 0             False
#
# [1 rows x 25 columns]

# %%
df['User_Location'].value_counts()
# Out:
# User_Location
# City35    72
# City68    69
# City73    66
# City37    65
# City69    64
#           ..
# City32    37
# City40    35
# City22    34
# City18    34
# City56    30
# Name: count, Length: 100, dtype: int64

# %%
counts = df['User_Location'].value_counts()
valid = counts[counts >= 60].index
df['User_Location'] = df['User_Location'].where(df['User_Location'].isin(valid), 'Others')

# %%
df['User_Location'].value_counts()
# Out:
# User_Location
# Others    4415
# City35      72
# City68      69
# City73      66
# City37      65
# City69      64
# City86      63
# City70      63
# City20      62
# City84      61
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df,columns = ['User_Location'])

# %%
df.head(1)
# Out:
#   Order_Date  Product_Price  Order_Quantity  Discount_Applied  User_Age  \
# 0 2022-01-14        1720.71               2             30.46        57
#
#    Return_Status  Order_Value  year  month  day  ...  User_Location_City20  \
# 0              0  2393.163468  2022      1   14  ...                 False
#
#    User_Location_City35  User_Location_City37  User_Location_City68  \
# 0                 False                 False                 False
#
#    User_Location_City69  User_Location_City70  User_Location_City73  \
# 0                 False                 False                 False
#
#    User_Location_City84  User_Location_City86  User_Location_Others
# 0                 False                 False                  True
#
# [1 rows x 34 columns]

# %%
df.astype(int)
# Out:
#             Order_Date  Product_Price  Order_Quantity  Discount_Applied  \
# 0     1642118400000000           1720               2                30
# 1     1641168000000000            744               5                29
# 2     1742083200000000            983               5                47
# 3     1730851200000000           1855               2                 2
# 4     1686096000000000           1770               5                44
# ...                ...            ...             ...               ...
# 4995  1723420800000000           1729               5                 4
# 4996  1724544000000000           1254               4                32
# 4997  1700006400000000           1183               3                31
# 4998  1704240000000000           1761               4                11
# 4999  1754611200000000           1975               1                39
#
#       User_Age  Return_Status  Order_Value  year  month  day  ...  \
# ...

# %%
df.dtypes
# Out:
# Order_Date                          datetime64[us]
# Product_Price                              float64
# Order_Quantity                               int64
# Discount_Applied                           float64
# User_Age                                     int64
# Return_Status                                int64
# Order_Value                                float64
# year                                         int32
# month                                        int32
# day                                          int32
# Product_Category_Books                        bool
# Product_Category_Clothing                     bool
# Product_Category_Electronics                  bool
# Product_Category_Home Appliances              bool
# Product_Category_Toys                         bool
# Shipping_Method_Express                       bool
# Shipping_Method_Next-Day                      bool
# Shipping_Method_Standard                      bool
# ...

# %%
df.drop('Order_Date', axis=1, inplace=True)

# %%
df = df.astype(int)

# %%
df.dtypes
# Out:
# Product_Price                       int64
# Order_Quantity                      int64
# Discount_Applied                    int64
# User_Age                            int64
# Return_Status                       int64
# Order_Value                         int64
# year                                int64
# month                               int64
# day                                 int64
# Product_Category_Books              int64
# Product_Category_Clothing           int64
# Product_Category_Electronics        int64
# Product_Category_Home Appliances    int64
# Product_Category_Toys               int64
# Shipping_Method_Express             int64
# Shipping_Method_Next-Day            int64
# Shipping_Method_Standard            int64
# Payment_Method_COD                  int64
# Payment_Method_Credit Card          int64
# Payment_Method_Debit Card           int64
# Payment_Method_Wallet               int64
# User_Gender_Female                  int64
# ...

# %%
df
# Out:
#       Product_Price  Order_Quantity  Discount_Applied  User_Age  \
# 0              1720               2                30        57
# 1               744               5                29        55
# 2               983               5                47        37
# 3              1855               2                 2        47
# 4              1770               5                44        35
# ...             ...             ...               ...       ...
# 4995           1729               5                 4        27
# 4996           1254               4                32        61
# 4997           1183               3                31        59
# 4998           1761               4                11        43
# 4999           1975               1                39        49
#
#       Return_Status  Order_Value  year  month  day  Product_Category_Books  \
# 0                 0         2393  2022      1   14                       0
# ...

# %%
df.columns
# Out:
# Index(['Product_Price', 'Order_Quantity', 'Discount_Applied', 'User_Age',
#        'Return_Status', 'Order_Value', 'year', 'month', 'day',
#        'Product_Category_Books', 'Product_Category_Clothing',
#        'Product_Category_Electronics', 'Product_Category_Home Appliances',
#        'Product_Category_Toys', 'Shipping_Method_Express',
#        'Shipping_Method_Next-Day', 'Shipping_Method_Standard',
#        'Payment_Method_COD', 'Payment_Method_Credit Card',
#        'Payment_Method_Debit Card', 'Payment_Method_Wallet',
#        'User_Gender_Female', 'User_Gender_Male', 'User_Location_City20',
#        'User_Location_City35', 'User_Location_City37', 'User_Location_City68',
#        'User_Location_City69', 'User_Location_City70', 'User_Location_City73',
#        'User_Location_City84', 'User_Location_City86', 'User_Location_Others'],
#       dtype='str')

# %%
pcc = df.corr(method='pearson')['Return_Status']
print(pcc)
# Out:
# Product_Price                       0.009355
# Order_Quantity                     -0.008031
# Discount_Applied                    0.078872
# User_Age                           -0.004605
# Return_Status                       1.000000
# Order_Value                        -0.015077
# year                                0.022107
# month                               0.006158
# day                                -0.009598
# Product_Category_Books             -0.060067
# Product_Category_Clothing           0.137273
# Product_Category_Electronics       -0.047673
# Product_Category_Home Appliances   -0.024089
# Product_Category_Toys              -0.045720
# Shipping_Method_Express             0.001344
# Shipping_Method_Next-Day           -0.007797
# Shipping_Method_Standard            0.006464
# Payment_Method_COD                  0.018745
# Payment_Method_Credit Card          0.025397
# Payment_Method_Debit Card          -0.019537
# Payment_Method_Wallet              -0.024017
# ...

# %%
from scipy.stats import chi2_contingency

alpha = 0.05
chi2_results = []

cat_features = [
    col for col in df.columns
    if col.startswith((
        'Product_Category_',
        'Shipping_Method_',
        'Payment_Method_',
        'User_Gender_',
        'User_Location_'
    ))
]

for col in cat_features:

    table = pd.crosstab(
        df[col],
        df['Return_Status']
    )

    chi2, p_value, dof, expected = chi2_contingency(table)

    if p_value < alpha:
        decision = "KEEP"
    else:
        decision = "REMOVE"

    chi2_results.append({
        'Feature': col,
        'Chi2': chi2,
        'P_Value': p_value,
        'Decision': decision
    })

chi2_df = pd.DataFrame(chi2_results)

print(chi2_df)
# Out:
#                              Feature       Chi2       P_Value Decision
# 0             Product_Category_Books  17.673516  2.622527e-05     KEEP
# 1          Product_Category_Clothing  93.587230  3.886873e-22     KEEP
# 2       Product_Category_Electronics  11.121899  8.531439e-04     KEEP
# 3   Product_Category_Home Appliances   2.723241  9.889700e-02   REMOVE
# 4              Product_Category_Toys  10.171821  1.426034e-03     KEEP
# 5            Shipping_Method_Express   0.003820  9.507179e-01   REMOVE
# 6           Shipping_Method_Next-Day   0.268659  6.042324e-01   REMOVE
# 7           Shipping_Method_Standard   0.179848  6.715038e-01   REMOVE
# 8                 Payment_Method_COD   1.661786  1.973624e-01   REMOVE
# 9         Payment_Method_Credit Card   3.096561  7.845787e-02   REMOVE
# 10         Payment_Method_Debit Card   1.811050  1.783824e-01   REMOVE
# 11             Payment_Method_Wallet   2.763905  9.641264e-02   REMOVE
# ...

# %%
# Features selected from Chi-Square
chi2_keep = [
    'Product_Category_Books',
    'Product_Category_Clothing',
    'Product_Category_Electronics',
    'Product_Category_Toys'
]

# Numerical features
num_features = [
    'Product_Price',
    'Order_Quantity',
    'Discount_Applied',
    'User_Age',
    'Order_Value',
    'year',
    'month',
    'day'
]

# Final features
final_features = num_features + chi2_keep

X_final = df[final_features]
y = df['Return_Status']

print("Selected Features:")
print(X_final.columns)

print("\nShape:", X_final.shape)
# Out:
# Selected Features:
# Index(['Product_Price', 'Order_Quantity', 'Discount_Applied', 'User_Age',
#        'Order_Value', 'year', 'month', 'day', 'Product_Category_Books',
#        'Product_Category_Clothing', 'Product_Category_Electronics',
#        'Product_Category_Toys'],
#       dtype='str')
#
# Shape: (5000, 12)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['Product_Price', 'Order_Quantity', 'Discount_Applied', 'User_Age',
       'Order_Value', 'year', 'month', 'day', 'Product_Category_Books',
       'Product_Category_Clothing', 'Product_Category_Electronics',
       'Product_Category_Toys']]

# %%
y = df['Return_Status']

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(random_state=42)
}

for name, model in models.items():

    model.fit(x_train_scaled, y_train)

    y_pred = model.predict(x_test_scaled)

    print("\n", "=" * 40)
    print(name)
    print("=" * 40)

    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# ...
# Logistic Regression
# ...
# Accuracy: 0.698
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82       698
#            1       0.00      0.00      0.00       302
#
#     accuracy                           0.70      1000
#    macro avg       0.35      0.50      0.41      1000
# weighted avg       0.49      0.70      0.57      1000
#
#
# ...
# Decision Tree
# ...
# Accuracy: 0.589
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71       698
#            1       0.31      0.29      0.30       302
#
#     accuracy                           0.59      1000
#    macro avg       0.50      0.50      0.50      1000
# weighted avg       0.58      0.59      0.59      1000
#
#
# ...
# Random Forest
# ...
# Accuracy: 0.692
#               precision    recall  f1-score   support
#
#            0       0.70      0.97      0.81       698
#            1       0.42      0.05      0.09       302
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Random Forest
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# Parameters to test
param_grid = {
    "n_estimators": [100, 200],
    "max_depth": [5, 10, None],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
    "class_weight": [None, "balanced"]
}

# GridSearchCV
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring="f1",
    n_jobs=-1
)

# Train
grid_search.fit(x_train_scaled, y_train)

# Best parameters
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest CV F1 Score:")
print(grid_search.best_score_)

# Best Random Forest
best_rf = grid_search.best_estimator_

# Test prediction
y_pred = best_rf.predict(x_test_scaled)

# Evaluation
print("\nTest Accuracy:")
print(accuracy_score(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Best Parameters:
# {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
#
# Best CV F1 Score:
# 0.41131197227145044
#
# Test Accuracy:
# 0.607
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.64      0.69       698
#            1       0.39      0.53      0.45       302
#
#     accuracy                           0.61      1000
#    macro avg       0.57      0.59      0.57      1000
# weighted avg       0.65      0.61      0.62      1000
#
#
# Confusion Matrix:
# [[447 251]
#  [142 160]]

# %%
final_model = best_rf

# %%
import joblib

# Save final model
joblib.dump(final_model, "final_random_forest.pkl")

# Save scaler
joblib.dump(scaler, "scaler.pkl")

print("Final model saved successfully!")
print("Scaler saved successfully!")
# Out:
# Final model saved successfully!
# Scaler saved successfully!
